# %%
# !pip install pymongo[srv] dnspython==2.2.1
# Out:
# ...
# WARNING: pymongo 4.13.2 does not provide the extra 'srv'

# %%
from pymongo import MongoClient

import getpass

username = getpass.getpass("Enter MongoDB username: ")
password = getpass.getpass("Enter MongoDB password: ")

uri = f"mongodb+srv://{username}:{password}@prateekcluster.zayurnw.mongodb.net/?retryWrites=true&w=majority&authSource=admin&tlsAllowInvalidCertificates=true"

client = MongoClient(uri)

# Select your DB and collection
db = client['olistDataNoSQL']
collection = db['olistData']

# Print all documents
for doc in collection.find():
    print(doc)
# Out:
# Enter MongoDB username: ··········
# Enter MongoDB password: ··········
# {'_id': ObjectId('6872978ddd169922170d3dfb'), 'product_category_name': 'beleza_saude', 'product_category_name_english': 'health_beauty'}
# {'_id': ObjectId('6872978ddd169922170d3dfc'), 'product_category_name': 'informatica_acessorios', 'product_category_name_english': 'computers_accessories'}
# {'_id': ObjectId('6872978ddd169922170d3dfd'), 'product_category_name': 'automotivo', 'product_category_name_english': 'auto'}
# {'_id': ObjectId('6872978ddd169922170d3dfe'), 'product_category_name': 'cama_mesa_banho', 'product_category_name_english': 'bed_bath_table'}
# {'_id': ObjectId('6872978ddd169922170d3dff'), 'product_category_name': 'moveis_decoracao', 'product_category_name_english': 'furniture_decor'}
# {'_id': ObjectId('6872978ddd169922170d3e00'), 'product_category_name': 'esporte_lazer', 'product_category_name_english': 'sports_leisure'}
# ...

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('product_category_name_translation.csv')

# Preview
df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
# Convert to dictionary records
records = df.to_dict(orient='records')

# Insert into your MongoDB collection
collection.insert_many(records)

print(f"{len(records)} documents inserted!")
# Out:
# 71 documents inserted!

# %%
for doc in collection.find().limit(5):
    print(doc)
# Out:
# {'_id': ObjectId('6872978ddd169922170d3dfb'), 'product_category_name': 'beleza_saude', 'product_category_name_english': 'health_beauty'}
# {'_id': ObjectId('6872978ddd169922170d3dfc'), 'product_category_name': 'informatica_acessorios', 'product_category_name_english': 'computers_accessories'}
# {'_id': ObjectId('6872978ddd169922170d3dfd'), 'product_category_name': 'automotivo', 'product_category_name_english': 'auto'}
# {'_id': ObjectId('6872978ddd169922170d3dfe'), 'product_category_name': 'cama_mesa_banho', 'product_category_name_english': 'bed_bath_table'}
# {'_id': ObjectId('6872978ddd169922170d3dff'), 'product_category_name': 'moveis_decoracao', 'product_category_name_english': 'furniture_decor'}
